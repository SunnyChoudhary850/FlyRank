# %% [markdown]
# <a href="https://colab.research.google.com/github/SunnyChoudhary850/FlyRank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring
#
# I already ran the starter notebooks, and the pipeline in this repo.

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/SunnyChoudhary850/FlyRank/main/data/raw/content_refresh_anonymized.csv")
df.shape
df.sample(5)
# Out:
#                  content_id          client_id  search_volume  competition  \
# 12888  content_2642dded10af  client_d4735e3a26            NaN          NaN
# 22633  content_994b0a4e4dde  client_98a3ab7c34            0.0          0.0
# 26669  content_503edccc7cfa  client_4ec9599fc2            NaN          NaN
# 4109   content_229689a85173  client_d029fa3a95           10.0          0.0
# 21303  content_6320064497fd  client_4e07408562           50.0          0.0
#
#       competition_level  cpc     content_type    main_intent  word_count  \
# 12888               NaN  NaN   feedly article            NaN       868.0
# 22633               LOW  0.0  keyword article  informational      2532.0
# 26669               NaN  NaN   feedly article            NaN      5246.0
# 4109                LOW  0.0  keyword article  informational      3662.0
# 21303               LOW  0.0  keyword article  informational      2446.0
#
# ...

# %%
length=len(df)
print(length)
down=(df['trend_direction']=='down').sum()
print(down)
impression=round(df['impressions_90d'].mean(), 1)
print(impression)
# Out:
# 30000
# 16262
# 5200.4

# %%
print("Total pages ",length)
print("Page with declining trend ",down)
print("Average of the 90 days impression ",impression )
# Out:
# Total pages  30000
# Page with declining trend  16262
# Average of the 90 days impression  5200.4
